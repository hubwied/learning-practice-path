# %% [markdown]
# # Klasy

# %% [markdown]
# ##  wstep

# %%
class Phone:
    pass

# %%
class Phone(object):
    pass

# %%
help(object)
# Out:
# Help on class object in module builtins:
#
# class object
#  |  The base class of the class hierarchy.
#  |
#  |  When called, it accepts no arguments and returns a new featureless
#  |  instance that has no instance attributes and cannot be given any.
#  |
#  |  Built-in subclasses:
#  |      anext_awaitable
#  |      async_generator
#  |      async_generator_asend
#  |      async_generator_athrow
#  |      ... and 92 other subclasses
#  |
#  |  Methods defined here:
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
#  |  __dir__(self, /)
#  |      Default dir() implementation.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Default object formatter.
#  |
#  |      Return str(self) if format_spec is empty. Raise TypeError otherwise.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
# ...

# %%
import builtins

builtins.object
# Out:
# object

# %%
help(Phone)
# Out:
# Help on class Phone in module __main__:
#
# class Phone(builtins.object)
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
class Phone:
    """ the phone class """
    
help(Phone)
# Out:
# Help on class Phone in module __main__:
#
# class Phone(builtins.object)
#  |  the phone class
#  |
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
Phone
# Out:
# __main__.Phone

# %%
Phone.__name__
# Out:
# 'Phone'

# %%
Phone.__module__
# Out:
# '__main__'

# %%
Phone.__doc__
# Out:
# 'the phone class '

# %%
 Phone()

# %%
phone = Phone()

# %%
phone

# %%
type(phone)
# Out:
# __main__.Phone

# %%
phone.__class__
# Out:
# __main__.Phone

# %%
phone.__class__.__name__
# Out:
# 'Phone'

# %%
phone1 = Phone()
phone2 = Phone()

# %%
phone1, phone2
# Out:
# (<__main__.Phone at 0x1facc989a90>, <__main__.Phone at 0x1faccf808a0>)

# %%
help(id)
# Out:
# Help on built-in function id in module builtins:
#
# id(obj, /)
#     Return the identity of an object.
#
#     This is guaranteed to be unique among simultaneously existing objects.
#     (CPython uses the object's memory address.)

# %%
id(phone1), id(phone2)
# Out:
# (2176686004880, 2176692258976)

# %%
phone1 is phone2
# Out:
# False

# %%
class HouseProject:
    
    def __init__(self, type_of_project):
        self.type_of_project = type_of_project

# %%
project1 = HouseProject("single-family")
project1

# %%
type(project1)
# Out:
# __main__.HouseProject

# %%
project1.type_of_project
# Out:
# 'single-family'

# %%
 project2 = HouseProject.__new__(HouseProject)
 project2

# %%
project2.type_of_project
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 project2.type_of_project
#
# AttributeError: 'HouseProject' object has no attribute 'type_of_project'

# %%
project2.__init__('dom 2')

# %%
project2.type_of_project
# Out:
# 'dom 2'

# %%
isinstance(project1, HouseProject)
# Out:
# True

# %%
isinstance(phone , Phone)
# Out:
# True

# %%
isinstance(HouseProject , type)
# Out:
# True

# %%
import pandas as pd

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
print(pd.__doc__)
# Out:
# pandas - a powerful data analysis and manipulation library for Python
# ...
#
# **pandas** is a Python package providing fast, flexible, and expressive data
# structures designed to make working with "relational" or "labeled" data both
# easy and intuitive. It aims to be the fundamental high-level building block for
# doing practical, **real world** data analysis in Python. Additionally, it has
# the broader goal of becoming **the most powerful and flexible open source data
# analysis / manipulation tool available in any language**. It is already well on
# its way toward this goal.
#
# Main Features
# -------------
# Here are just a few of the things that pandas does well:
#
#   - Easy handling of missing data in floating point as well as non-floating
#     point data.
#   - Size mutability: columns can be inserted and deleted from DataFrame and
#     higher dimensional objects
#   - Automatic and explicit data alignment: objects can be explicitly aligned
# ...

# %%
pd.__file__
# Out:
# 'e:\\anaconda\\Lib\\site-packages\\pandas\\__init__.py'

# %%
pd.__name__
# Out:
# 'pandas'

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
pd.DataFrame.__module__
# Out:
# 'pandas.core.frame'

# %%
pd.__dict__
# Out:
# {'__name__': 'pandas',
# ...

# %%
df = pd.DataFrame(data=[1,2,3])
df
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
Phone.__bases__
# Out:
# (object,)

# %%
class Phone:
    
    sector = 'electronics'
    os = 'android'
    width = 5.5
    height = 2.5

# %%
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'sector': 'electronics',
#               'os': 'android',
#               'width': 5.5,
#               'height': 2.5,
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>,
#               '__doc__': None})

# %%
Phone.__dict__.keys()
# Out:
# dict_keys(['__module__', '__firstlineno__', 'sector', 'os', 'width', 'height', '__static_attributes__', '__dict__', '__weakref__', '__doc__'])

# %%
Phone.height
# Out:
# 2.5

# %%
 getattr(Phone, 'height')
# Out:
# 2.5

# %%
Phone.color
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 Phone.color
#
# AttributeError: type object 'Phone' has no attribute 'color'

# %%
getattr(Phone, 'color', 'black')
# Out:
# 'black'

# %%
for attr in sorted(Phone.__dict__.keys()):
    if not attr.startswith('__'):
        print(attr, getattr(Phone, attr))

# %%
class Phone:
    
    sector = 'electronics'
    os = 'android'
    width = 5.5
    height = 2.5

# %%
Phone.os
# Out:
# 'android'

# %%
Phone.os = 'ios'

# %%
Phone.os
# Out:
# 'ios'

# %%
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'sector': 'electronics',
#               'os': 'ios',
#               'width': 5.5,
#               'height': 2.5,
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>,
#               '__doc__': None})

# %%
setattr(Phone, 'os', 'android')

# %%
Phone.os
# Out:
# 'android'

# %%
getattr(Phone, 'os')
# Out:
# 'android'

# %%
Phone.origin_country = 'USA'

# %%
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'sector': 'electronics',
#               'os': 'android',
#               'width': 5.5,
#               'height': 2.5,
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>,
#               '__doc__': None,
#               'origin_country': 'USA'})

# %%
setattr(Phone, 'year_of_production', '2020')

# %%
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'sector': 'electronics',
#               'os': 'android',
#               'width': 5.5,
#               'height': 2.5,
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>,
#               '__doc__': None,
#               'origin_country': 'USA',
#               'year_of_production': '2020'})

# %% [markdown]
# ## usuwanie atrybutu klasy

# %%
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'sector': 'electronics',
#               'os': 'android',
#               'width': 5.5,
#               'height': 2.5,
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>,
#               '__doc__': None,
#               'origin_country': 'USA',
#               'year_of_production': '2020'})

# %%
del Phone.os

# %%
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'sector': 'electronics',
#               'width': 5.5,
#               'height': 2.5,
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>,
#               '__doc__': None,
#               'origin_country': 'USA',
#               'year_of_production': '2020'})

# %%
delattr(Phone, 'year_of_production')

# %%
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'sector': 'electronics',
#               'width': 5.5,
#               'height': 2.5,
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>,
#               '__doc__': None,
#               'origin_country': 'USA'})

# %% [markdown]
# ## Wywoływanie atrybutu klasy

# %%
class Phone:
    
    sector = 'electronics'
    os = 'android'
    width = 5.5
    height = 2.5

    def describe_class(): 
        print('Phone class')

# %%
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'sector': 'electronics',
#               'os': 'android',
#               'width': 5.5,
#               'height': 2.5,
#               'describe_class': <function __main__.Phone.describe_class()>,
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>,
#               '__doc__': None})

# %%
Phone.describe_class
# Out:
# <function __main__.Phone.describe_class()>

# %%
Phone.describe_class()
# Out:
# Phone class

# %%
class Phone:
    
    sector = 'electronics'
    os = 'android'
    width = 5.5
    height = 2.5

    def describe_class(): 
        print(f'{Phone} class')
        
Phone.describe_class()
# Out:
# <class '__main__.Phone'> class

# %%
class Phone:
    
    sector = 'electronics'
    os = 'android'
    width = 5.5
    height = 2.5

    def describe_class(): 
        print(f'{Phone.__name__} class')
        
Phone.describe_class()
# Out:
# Phone class

# %%
class Phone:
    
    sector = 'electronics'
    os = 'android'
    width = 5.5
    height = 2.5

    def describe_class():
        """print class name and operating system""" 
        print(f'Operating system: {Phone.os}')
        print(f'{Phone.__name__} class')
        
Phone.describe_class()
# Out:
# Operating system: android
# Phone class

# %%
getattr(Phone,'describe_class')()
# Out:
# Operating system: android
# Phone class

# %%
help(Phone)
# Out:
# Help on class Phone in module __main__:
#
# class Phone(builtins.object)
#  |  Methods defined here:
#  |
#  |  describe_class()
#  |      print class name and operating system
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  height = 2.5
#  |
#  |  os = 'android'
#  |
#  |  sector = 'electronics'
#  |
#  |  width = 5.5

# %% [markdown]
# ### zadanie

# %%
class HouseProject:
    
    number_of_floors = 2
    area = 100

# %%
HouseProject.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'number_of_floors': 2,
#               'area': 100,
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'HouseProject' objects>,
#               '__weakref__': <attribute '__weakref__' of 'HouseProject' objects>,
#               '__doc__': None})

# %%
class HouseProject:
    
    number_of_floors = 2
    area = 100 
    
    def describe_project(): 
        print (f'Area: {HouseProject.area} m2.')
        print (f'number of floors: {HouseProject.number_of_floors}.')

# %%
HouseProject.describe_project()
# Out:
# Area: 100 m2.
# number of floors: 2.

# %% [markdown]
# ## przykład

# %%
from datetime import datetime

datetime.now().strftime('%H:%M:%S')
# Out:
# '00:48:17'

# %%
class Foto:
    
    execution_time = datetime.now().strftime('%H_%M_%S') 
    fname = 'image_' + execution_time + '.jpg'
    
Foto.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'execution_time': '00_50_04',
#               'fname': 'image_00_50_04.jpg',
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Foto' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Foto' objects>,
#               '__doc__': None})

# %%
Foto.execution_time
# Out:
# '00_50_04'

# %%
Foto.fname
# Out:
# 'image_00_50_04.jpg'

# %%
foto = Foto()
foto.execution_time
# Out:
# '00_50_04'

# %%
class Foto:
    
    execution_time = datetime.now().strftime('%H_%M_%S') 
    fname = 'image_' + execution_time + '.jpg'
    
    def current_time():
        return datetime.now().strftime('%H_%M_%S')
    
Foto.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'execution_time': '00_54_18',
#               'fname': 'image_00_54_18.jpg',
#               'current_time': <function __main__.Foto.current_time()>,
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Foto' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Foto' objects>,
#               '__doc__': None})

# %%
Foto.current_time()
# Out:
# '00_54_26'

# %%
Foto.__mro__
# Out:
# (__main__.Foto, object)

# %% [markdown]
# ## atrybuty instancji

# %%
class Book: 
    
    language = 'English'
    
    def show():
        print(f'Language: {Book.language}')
        
Book.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'language': 'English',
#               'show': <function __main__.Book.show()>,
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Book' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Book' objects>,
#               '__doc__': None})

# %%
book1 = Book()
book1

# %%
type(book1), type(Book)
# Out:
# (__main__.Book, type)

# %%
isinstance(book1, Book)
# Out:
# True

# %% [markdown]
# ### wbydowane atrybuty klasy vs wbudowane atrybuty instacji

# %%
class Book: 
    
    language = 'English'
    
    def show():
        print(f'Language: {Book.language}')
        
Book.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'language': 'English',
#               'show': <function __main__.Book.show()>,
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Book' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Book' objects>,
#               '__doc__': None})

# %%
book1.__dict__
# Out:
# {}

# %% [markdown]
# ### atrybuty klasy oraz atrybuty instancji

# %%
book1 = Book()
book2 = Book()
book1, book2
# Out:
# (<__main__.Book at 0x1facc989e50>, <__main__.Book at 0x1faccf809d0>)

# %%
book1.language
# Out:
# 'English'

# %%
Book.author = 'John Smith'

# %%
book1.author,book2.author
# Out:
# ('John Smith', 'John Smith')

# %%
book1.author = 'Adam Mickiewicz'

# %%
book1.author, book2.author, Book.author
# Out:
# ('Adam Mickiewicz', 'John Smith', 'John Smith')

# %%
book1.__dict__, book2.__dict__
# Out:
# ({'author': 'Adam Mickiewicz'}, {})

# %%
del book1.author

# %%
book1.author
# Out:
# 'John Smith'

# %%
class Book: 
    
    language = 'English'
    
    def show():
        print(f'Language: {Book.language}')
        
book1 = Book()
book2 = Book()
book1, book2
# Out:
# (<__main__.Book at 0x1faccf1e120>, <__main__.Book at 0x1facc98a0d0>)

# %%
book1.__dict__, book2.__dict__
# Out:
# ({}, {})

# %%
book1.title = 'Pan Tadeusz'
book2.year = 1834

# %%
book1.__dict__, book2.__dict__
# Out:
# ({'title': 'Pan Tadeusz'}, {'year': 1834})

# %%
Book.title
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 Book.title
#
# AttributeError: type object 'Book' has no attribute 'title'

# %%
class Book: 
    
    language = 'English'
    author = 'John Smith'
    
    def show():
        print(f'Language: {Book.language}')
        
Book.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'language': 'English',
#               'author': 'John Smith',
#               'show': <function __main__.Book.show()>,
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Book' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Book' objects>,
#               '__doc__': None})

# %%
books = [Book() for i in range(3)]
books

# %%
for book in books:
    print(f'language: {book.language}, author: {book.author}')
# Out:
# language: English, author: John Smith
# language: English, author: John Smith
# language: English, author: John Smith

# %%
titles = ['Pan Tadeusz', 'Wesele', 'Lalka']

for book, title in zip(books, titles):
    book.title = title

# %%
for book in books:
    print(f'language: {book.language}, author: {book.author}, title: {book.title}')
# Out:
# language: English, author: John Smith, title: Pan Tadeusz
# language: English, author: John Smith, title: Wesele
# language: English, author: John Smith, title: Lalka

# %%
for book in books:
    print(book.__dict__)
# Out:
# {'title': 'Pan Tadeusz'}
# {'title': 'Wesele'}
# {'title': 'Lalka'}

# %%
class Book: 
    
    language = 'English'
    author = 'John Smith'
    
    def show():
        print(f'Language: {Book.language},\n Author: {Book.author}')
        
Book.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'language': 'English',
#               'author': 'John Smith',
#               'show': <function __main__.Book.show()>,
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Book' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Book' objects>,
#               '__doc__': None})

# %%
Book.show()
# Out:
# Language: English,
#  Author: John Smith

# %%
Book.show_language = lambda: print(f'Language: {Book.language}')

# %%
Book.show_language()
# Out:
# Language: English

# %%
Book1 = Book()

# %%
book1.show
# Out:
# <bound method Book.show of <__main__.Book object at 0x000001FACCF1E120>>

# %%
book1.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 book1.show()
#
# TypeError: Book.show() takes 0 positional arguments but 1 was given

# %%
type(book1.show), type(Book.show)
# Out:
# (method, function)

# %%
class Book: 
    
    language = 'English'
    author = 'John Smith'
    
    def show_details(*args):
        print(args) 
        for arg in args:
            print(f'{arg} -> {type(arg)} ')
        
Book.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'language': 'English',
#               'author': 'John Smith',
#               'show_details': <function __main__.Book.show_details(*args)>,
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Book' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Book' objects>,
#               '__doc__': None})

# %%
Book.show_details()
# Out:
# ()

# %%
book1 = Book()
book1.show_details()
# Out:
# (<__main__.Book object at 0x0000013537C70D70>,)
# <__main__.Book object at 0x0000013537C70D70> -> <class '__main__.Book'>

# %%
book1.show_details('Tom II')
# Out:
# (<__main__.Book object at 0x0000013537C70D70>, 'Tom II')
# <__main__.Book object at 0x0000013537C70D70> -> <class '__main__.Book'>
# Tom II -> <class 'str'>

# %%
class Book: 
    
    language = 'English'
    author = 'John Smith'
    
    def set_title(instance, value):
        instance.title = value

# %%
book1 = Book()
book1

# %%
book1.set_title('Pan Tadeusz')

# %%
book1.__dict__
# Out:
# {'title': 'Pan Tadeusz'}

# %%
Book.title
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 Book.title
#
# AttributeError: type object 'Book' has no attribute 'title'

# %%
Book.set_title(book1,'Chlopi')

# %%
book1.__dict__
# Out:
# {'title': 'Chlopi'}

# %%
class HouseProject:
    
    number_of_floors = 2
    area = 100 
    
    def describe_project(): 
        print (f'Area: {HouseProject.area} m2.')
        print (f'number of floors: {HouseProject.number_of_floors}.')
        
    def set_color(self, value):
        self.color = value

# %%
project1 = HouseProject()
project1

# %%
project1.__dict__
# Out:
# {}

# %%
project1.set_color('red')

# %%
project1.__dict__
# Out:
# {'color': 'red'}

# %%
class Phone:
    
    brand = 'Samsung'
    short_name = 'S20'
    
    def print_brand():
        print (f'Brand: {Phone.brand}, short name: {Phone.short_name}')

# %%
class Phone:
    
    def __init__(self, brand,):
        self.brand = brand
    
    def print_brand(self):
        print (f'Brand: {self.brand}')

# %%
phone1 = Phone('Samsung')

# %%
phone1.print_brand()
# Out:
# Brand: Samsung

# %%
class Phone:
    
    brand = 'Samsung'
    
    def __init__(self, brand,):
        self.brand = brand
        
    def print_brand(self):
        print (f'wartosc atrybutu klasy: {Phone.brand}')
        print (f'wartosc atrybutu instancji: {self.brand}')    
        
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'brand': 'Samsung',
#               '__init__': <function __main__.Phone.__init__(self, brand)>,
#               'print_brand': <function __main__.Phone.print_brand(self)>,
#               '__static_attributes__': ('brand',),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>,
#               '__doc__': None})

# %%
phone1 = Phone('Apple')
phone1.print_brand()
# Out:
# wartosc atrybutu klasy: Samsung
# wartosc atrybutu instancji: Apple

# %%
brand = 'Nokia'

class Phone: 
    
    brand = 'Apple'
    result1 = [brand] * 5 
    result2 = [brand for i in range(5) ]
    
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 3,
#               'brand': 'Apple',
#               'result1': ['Apple', 'Apple', 'Apple', 'Apple', 'Apple'],
#               'result2': ['Nokia', 'Nokia', 'Nokia', 'Nokia', 'Nokia'],
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>,
#               '__doc__': None})

# %% [markdown]
# ## metoda __init__()

# %%
class Phone: 
    """"Phone class """
    
help(Phone)
# Out:
# Help on class Phone in module __main__:
#
# class Phone(builtins.object)
#  |  "Phone class
#  |
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
class Phone: 
    """"Phone class """
    
    def __init__(self):
        print(f'inicjalizacja instancji klasy Phone {self}')

# %%
Phone()
# Out:
# inicjalizacja instancji klasy Phone <__main__.Phone object at 0x000001F369B3BB60>

# %%
phone1 = Phone()
# Out:
# inicjalizacja instancji klasy Phone <__main__.Phone object at 0x000001F369C58A50>

# %%
phone2 = Phone.__new__(Phone)

# %%
phone2.__init__()
# Out:
# inicjalizacja instancji klasy Phone <__main__.Phone object at 0x000001F369BA75C0>

# %%
class Phone: 
    """"Phone class """
    
    def __init__(self, value):
        print(f'inicjalizacja instancji klasy Phone {self}')
        self.brand = value

# %%
phone2 = Phone('Apple')
# Out:
# inicjalizacja instancji klasy Phone <__main__.Phone object at 0x000001F369C95010>

# %%
class Phone: 
    """"Phone class """
    
    def __init__(self, brand):
        self.brand = brand

# %%
class Laptop: 
    """"Laptop class """
    
    def __init__(self, brand,model,price):
        self.brand = brand
        self.model = model
        self.price = price

# %%
laptop1 = Laptop('Apple', 'MacBook Pro', 2500)

# %%
laptop1.__dict__
# Out:
# {'brand': 'Apple', 'model': 'MacBook Pro', 'price': 2500}

# %%
class Laptop: 
    """"Laptop class """
    
    def __init__(self, brand,model,price):
        self.brand = brand
        self.model = model
        self.price = price
        
    def show_attrs(self):
        for attr in self.__dict__.keys():
            print(f'{attr}')

# %%
laptop1.show_attrs()
# Out:
# brand
# model
# price

# %%
class Laptop: 
    """"Laptop class """
    
    def __init__(self, brand,model,price):
        self.brand = brand
        self.model = model
        self.price = price
        
    def show_attrs(self):
        for attr in self.__dict__.keys():
            print(f'{attr}')
            
    def show_values(self):
        for item,value in self.__dict__.items():
            print(f'{item} - {value} ')

# %%
laptop1 = Laptop('Apple', 'MacBook Pro', 2500)

# %%
laptop1.show_values()
# Out:
# brand - Apple
# model - MacBook Pro
# price - 2500

# %%
class Vector: 
    
    def __init__(self, *args):
        self.components = args

# %%
v1 = Vector(1,2,3)

# %%
v1.__dict__
# Out:
# {'components': (1, 2, 3)}

# %%
class TechStack:
    
    def __init__(self, **techs):
        self.techs = techs

# %%
stack = TechStack(frontend='React', backend='Django', database='PostgreSQL')

# %%
stack.techs
# Out:
# {'frontend': 'React', 'backend': 'Django', 'database': 'PostgreSQL'}

# %%
class TechStack:
    
    def __init__(self, **techs):
        for key, value in techs.items():
            setattr(self, key, value)

# %%
stack1 = TechStack(frontend='React', backend='Django', database='PostgreSQL')

# %%
stack1.__dict__
# Out:
# {'frontend': 'React', 'backend': 'Django', 'database': 'PostgreSQL'}

# %%
class TechStack:
    
    def __init__(self, **techs):
        for key, value in techs.items():
            setattr(self, key, value)
            
    def display_info(self):
        print(f'{len(self.__dict__)} technologies in the stack:')

# %%
stack1.display_info()
# Out:
# 3 technologies in the stack:

# %%
class Phone: 
    """"Phone class """
    
    def __init__(self, brand,model,price):
        self.brand = brand
        self.model = model
        if isinstance(price, (int, float)):
            self.price = price
        else:
            raise TypeError("Price must be a number")

phone1 = Phone('Apple', 'iPhone 12', 999)
phone1.brand,phone1.model, phone1.price
# Out:
# ('Apple', 'iPhone 12', 999)

# %%
phone2 = Phone('Samsung', 'Galaxy S21', 'aaa')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 phone2 = Phone('Samsung', 'Galaxy S21', 'aaa')
#
# Cell In[53], line 10, in Phone.__init__(self, brand, model, price)
#       8     self.price = price
#       9 else:
# ---> 10     raise TypeError("Price must be a number")
#
# TypeError: Price must be a number

# %%
class Phone: 
    """"Phone class """
    
    def __init__(self, brand,model,price):
        self.brand = brand
        self.model = model
        if isinstance(price, (int, float)):
            self.price = price
        else:
            raise TypeError("Price must be a number")
        
    def show_details(self):
        print(f'Brand: {self.brand},\nmodel: {self.model},\nprice: {self.price}')

# %%
phone2 = Phone('Samsung', 'Galaxy S21', 899)

# %%
phone2.show_details()
# Out:
# Brand: Samsung,
# model: Galaxy S21,
# price: 899

# %%
class Phone: 
    """"Phone class """
    
    def __init__(self, brand,model,price):
        self.brand = brand
        self.model = model
        if isinstance(price, (int, float)):
            self.price = price
        else:
            raise TypeError("Price must be a number")
        
    def show_details(self):
        print(f'Brand: {self.brand},\nmodel: {self.model},\nprice: {self.price}')
        
    def usd_to_pln(self):
        self.price = self.price * 4.2
        
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__doc__': '"Phone class ',
#               '__init__': <function __main__.Phone.__init__(self, brand, model, price)>,
#               'show_details': <function __main__.Phone.show_details(self)>,
#               'usd_to_pln': <function __main__.Phone.usd_to_pln(self)>,
#               '__static_attributes__': ('brand', 'model', 'price'),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>})

# %%
phone2 = Phone('Samsung', 'Galaxy S21', 899)

# %%
phone2.usd_to_pln()

# %%
phone2.price
# Out:
# 3775.8

# %%
class TechStack:
    
    def __init__(self, tech = None):
        self.tech = tech

# %%
stack = TechStack()

# %%
stack.tech

# %%
stack = TechStack('Python')

# %%
stack.tech
# Out:
# 'Python'

# %%
class TechStack:
    
    def __init__(self, tech = None):
        self.tech = tech if tech else 'python'
        
    def display_info(self):
        if self.tech:
            print(f'Technology: {self.tech}')
        else:
            print('No technology specified')

# %%
stack = TechStack()
stack.display_info()
# Out:
# Technology: python

# %% [markdown]
# ## widoczność zmiennych

# %%
class Laptop:

    brand = 'Apple'
    
Laptop.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'brand': 'Apple',
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Laptop' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Laptop' objects>,
#               '__doc__': None})

# %%
class Laptop:

    brand = 'Apple'
    _code = '1234'
    
Laptop.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'brand': 'Apple',
#               '_code': '1234',
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Laptop' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Laptop' objects>,
#               '__doc__': None})

# %%
class Laptop:

    brand = 'Apple'
    _code = '1234'
    __wholesale_price = '56'
    
Laptop.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'brand': 'Apple',
#               '_code': '1234',
#               '_Laptop__wholesale_price': '56',
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Laptop' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Laptop' objects>,
#               '__doc__': None})

# %%
Laptop.__wholesale_price
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Laptop.__wholesale_price
#
# AttributeError: type object 'Laptop' has no attribute '__wholesale_price'

# %%
Laptop._Laptop__wholesale_price
# Out:
# '56'

# %%
class Laptop:
    
    brand = 'Apple'
    _usdpln = 4.2
    __trade_margin = 0.2
    
    def __init__(self,net_price):
        self.net_price = net_price
        
    def convert_to_pln(price):
        return price * Laptop._usdpln + (1+ Laptop._Laptop__trade_margin)
    
    def display_price(self):
        print(Laptop.convert_to_pln(self.net_price))

# %%
laptop = Laptop(1000)
laptop.display_price()
# Out:
# 4201.2

# %%
class Laptop:
    
    brand = 'Apple'
    _usdpln = 4.2
    __trade_margin = 0.2
    
    def __init__(self,net_price):
        self.net_price = net_price
        
    def __convert_to_pln(price):
        return price * Laptop._usdpln + (1+ Laptop._Laptop__trade_margin)
    
    def display_price(self):
        print(Laptop.__convert_to_pln(self.net_price))

# %%
class Laptop:
    
    def __init__(self,brand):
        self.brand = brand
            
laptop1 = Laptop('Apple')
laptop.brand
# Out:
# 'Apple'

# %%
class Laptop:
    
    def __init__(self,brand, code):
        self.brand = brand
        self._code = code
            
laptop1 = Laptop('Apple', '1234')
laptop1._code
# Out:
# '1234'

# %%
class Laptop:
    
    def __init__(self,brand, code, wholesale_price):
        self.brand = brand
        self._code = code
        self.__wholesale_price = wholesale_price
            
laptop1 = Laptop('Apple', '1234', 1000)
laptop1.__wholesale_price
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 9
#       6         self.__wholesale_price = wholesale_price
#       8 laptop1 = Laptop('Apple', '1234', 1000)
# ----> 9 laptop1.__wholesale_price
#
# AttributeError: 'Laptop' object has no attribute '__wholesale_price'

# %%
class Laptop:
    
    def __init__(self,brand, code, wholesale_price):
        self.brand = brand
        self._code = code
        self.__wholesale_price = wholesale_price
            
laptop1 = Laptop('Apple', '1234',1000)
laptop1._Laptop__wholesale_price
# Out:
# 1000

# %%
laptop1.__dict__
# Out:
# {'brand': 'Apple', '_code': '1234', '_Laptop__wholesale_price': 1000}

# %%
class Laptop:
    
    def __init__(self,brand, code, wholesale_price):
        self.brand = brand
        self._code = code
        self.__wholesale_price = wholesale_price
        
        
    def info(self):
        print(self.brand, self._code, self.__wholesale_price)
            
laptop1 = Laptop('Apple', '1234',1000)
laptop1._Laptop__wholesale_price
# Out:
# 1000

# %%
laptop1.info()
# Out:
# Apple 1234 1000

# %% [markdown]
# ## HERMETYZCJA

# %%
class Phone:
    
    def __init__(self, price):
        self.price = price
        
        
phone = Phone(999)
phone.__dict__
# Out:
# {'price': 999}

# %%
class Phone:
    
    def __init__(self, price):
        self._price = price
        
    def get_price(self):
        return self._price
    
    def set_price(self, value):
        if isinstance(value, (int, float)):
            self._price = value
        else:
            raise TypeError("Price must be a number")
 
        
phone = Phone(999)
phone.__dict__
# Out:
# {'_price': 999}

# %%
phone.get_price()
# Out:
# 999

# %%
phone.set_price(1099)

# %%
phone.get_price()
# Out:
# 1099

# %%
phone.set_price('1099')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 phone.set_price('1099')
#
# Cell In[10], line 13, in Phone.set_price(self, value)
#      11     self._price = value
#      12 else:
# ---> 13     raise TypeError("Price must be a number")
#
# TypeError: Price must be a number

# %%
phone.set_price(-2099)

# %%
phone.get_price()
# Out:
# -2099

# %%
class Phone:
    
    def __init__(self, price):
        self._price = price
        
    def get_price(self):
        return self._price
    
    def set_price(self, value):
        if isinstance(value, (int, float)):
            if value > 0:
                self._price = value
            else:
                raise ValueError("Price must be a positive number")
        else:
            raise TypeError("Price must be a number")
 
        
phone = Phone(999)
phone.__dict__
# Out:
# {'_price': 999}

# %%
phone.set_price(-1099)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 phone.set_price(-1099)
#
# Cell In[14], line 14, in Phone.set_price(self, value)
#      12         self._price = value
#      13     else:
# ---> 14         raise ValueError("Price must be a positive number")
#      15 else:
#      16     raise TypeError("Price must be a number")
#
# ValueError: Price must be a positive number

# %%
phone2 = Phone('apple')

# %%
phone2.get_price()
# Out:
# 'apple'

# %%
class Phone:
    
    def __init__(self, price):
        self.set_price(price)

        
    def get_price(self):
        return self._price
    
    def set_price(self, value):
        if isinstance(value, (int, float)):
            if value > 0:
                self._price = value
            else:
                raise ValueError("Price must be a positive number")
        else:
            raise TypeError("Price must be a number")
 
        
phone = Phone(999)
phone.__dict__
# Out:
# {'_price': 999}

# %%
phone3 = Phone('-22')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 phone3 = Phone('-22')
#
# Cell In[22], line 4, in Phone.__init__(self, price)
#       3 def __init__(self, price):
# ----> 4     self.set_price(price)
#
# Cell In[22], line 17, in Phone.set_price(self, value)
#      15         raise ValueError("Price must be a positive number")
#      16 else:
# ---> 17     raise TypeError("Price must be a number")
#
# TypeError: Price must be a number

# %% [markdown]
# ### property()

# %%
help(property)
# Out:
# Help on class property in module builtins:
#
# class property(object)
#  |  property(fget=None, fset=None, fdel=None, doc=None)
#  |
#  |  Property attribute.
#  |
#  |    fget
#  |      function to be used for getting an attribute value
#  |    fset
#  |      function to be used for setting an attribute value
#  |    fdel
#  |      function to be used for del'ing an attribute
#  |    doc
#  |      docstring
#  |
#  |  Typical use is to define a managed attribute x:
#  |
#  |  class C(object):
#  |      def getx(self): return self._x
#  |      def setx(self, value): self._x = value
#  |      def delx(self): del self._x
#  |      x = property(getx, setx, delx, "I'm the 'x' property.")
#  |
#  |  Decorators make defining new properties or modifying existing ones easy:
#  |
#  |  class C(object):
#  |      @property
#  |      def x(self):
#  |          "I am the 'x' property."
#  |          return self._x
#  |      @x.setter
#  |      def x(self, value):
#  |          self._x = value
# ...

# %%
class Phone:
    
    def __init__(self, price):
        self._price = price
    
    def get_price(self):
        print('Getting price...')
        return self._price
    
    price = property(fget=get_price)
    
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Phone.__init__(self, price)>,
#               'get_price': <function __main__.Phone.get_price(self)>,
#               'price': <property at 0x20790957ba0>,
#               '__static_attributes__': ('_price',),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>,
#               '__doc__': None})

# %%
phone = Phone(999)
phone.get_price()
# Out:
# Getting price...
# 999

# %%
phone.price
# Out:
# Getting price...
# 999

# %%
class Phone:
    
    def __init__(self, price):
        self._price = price
    
    def price(self):
        print('Getting price...')
        return self._price
    
    price = property(fget=price)
    
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Phone.__init__(self, price)>,
#               'price': <property at 0x20790f4b380>,
#               '__static_attributes__': ('_price',),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>,
#               '__doc__': None})

# %%
phone.price = 3000
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 phone.price = 3000
#
# AttributeError: property 'price' of 'Phone' object has no setter

# %%
del phone.price
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 del phone.price
#
# AttributeError: property 'price' of 'Phone' object has no deleter

# %%
class Phone:
    
    def __init__(self, price):
        self._price = price
    
    def price(self):
        print('Getting price...')
        return self._price
    
    def set_price(self,price):
        print('setting...')
        if isinstance(price,(int,float)):
            if price > 0: 
                self._price = price
            else:
                raise ValueError('price must be positive')
        else: 
            raise TypeError('price must be float or int')
         
    
    price = property(fget=price, fset=set_price)
    
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Phone.__init__(self, price)>,
#               'price': <property at 0x20791043380>,
#               'set_price': <function __main__.Phone.set_price(self, price)>,
#               '__static_attributes__': ('_price',),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>,
#               '__doc__': None})

# %%
phone = Phone(1111)
phone.price
# Out:
# Getting price...
# 1111

# %%
phone.price = 4444
# Out:
# setting...

# %%
phone.price
# Out:
# Getting price...
# 4444

# %%
phone.__dict__
# Out:
# {'_price': 4444}

# %%
phone.price = -3333
# Out:
# setting...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 phone.price = -3333
#
# Cell In[18], line 16, in Phone.set_price(self, price)
#      14         self._price = price
#      15     else:
# ---> 16         raise ValueError('price must be positive')
#      17 else:
#      18     raise TypeError('price must be float or int')
#
# ValueError: price must be positive

# %%
del phone.price
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 del phone.price
#
# AttributeError: property 'price' of 'Phone' object has no deleter

# %%
class Phone:
    
    def __init__(self, price):
        self._price = price
    
    def price(self):
        print('Getting price...')
        return self._price
    
    def set_price(self,price):
        print('setting...')
        if isinstance(price,(int,float)):
            if price > 0: 
                self._price = price
            else:
                raise ValueError('price must be positive')
        else: 
            raise TypeError('price must be float or int')
         
    def del_price(self):
        print('deletting...')
        del self._price
    
    price = property(fget=price, fset=set_price, fdel=del_price)
    
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Phone.__init__(self, price)>,
#               'price': <property at 0x207910cf380>,
#               'set_price': <function __main__.Phone.set_price(self, price)>,
#               'del_price': <function __main__.Phone.del_price(self)>,
#               '__static_attributes__': ('_price',),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>,
#               '__doc__': None})

# %%
phone = Phone(1111)
phone.price
# Out:
# Getting price...
# 1111

# %%
del phone.price
# Out:
# deletting...

# %%
phone.price
# Out:
# Getting price...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 phone.price
#
# Cell In[25], line 8, in Phone.price(self)
#       6 def price(self):
#       7     print('Getting price...')
# ----> 8     return self._price
#
# AttributeError: 'Phone' object has no attribute '_price'

# %%
class Phone:
    """phone class docs."""
    
    def __init__(self, price):
        self._price = price
    
    def price(self):
        print('Getting price...')
        return self._price
    
    def set_price(self,price):
        print('setting...')
        if isinstance(price,(int,float)):
            if price > 0: 
                self._price = price
            else:
                raise ValueError('price must be positive')
        else: 
            raise TypeError('price must be float or int')
         
    def del_price(self):
        print('deletting...')
        del self._price
    
    price = property(fget=price, fset=set_price, fdel=del_price, doc='Phone price.')
    
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__doc__': 'phone class docs.',
#               '__init__': <function __main__.Phone.__init__(self, price)>,
#               'price': <property at 0x20790fdfec0>,
#               'set_price': <function __main__.Phone.set_price(self, price)>,
#               'del_price': <function __main__.Phone.del_price(self)>,
#               '__static_attributes__': ('_price',),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>})

# %%
help(Phone)
# Out:
# Help on class Phone in module __main__:
#
# class Phone(builtins.object)
#  |  Phone(price)
#  |
#  |  phone class docs.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, price)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  del_price(self)
#  |
#  |  set_price(self, price)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  price
#  |      Phone price.

# %% [markdown]
# ### dekoratory

# %%
def hello():
    print('Python 3.8')
    
hello()
# Out:
# Python 3.8

# %%
def pretty_print(func):
    def wrapper():
        print('='*30)
        func()
        print('='*30)
    return wrapper 

pretty_print(hello)
# Out:
# <function __main__.pretty_print.<locals>.wrapper()>

# %%
pretty_print(hello)()
# Out:
# ...
# Python 3.8
# ...

# %%
hello = pretty_print(hello)
hello()
# Out:
# ...
# Python 3.8
# ...

# %%
def pretty_print(func):
    def wrapper():
        print('='*30)
        func()
        print('='*30)
    return wrapper 

@pretty_print
def hello():
    print('Python 3.8')

# %%
hello()
# Out:
# ...
# Python 3.8
# ...

# %%
import time 

time.time()
# Out:
# 1784929689.791557

# %%
time.sleep(2)

# %%
def timer(func):
    def wrapper(sec):
        start = time.time()
        func(sec)
        stop = time.time()
        print(f'Execution time {stop-start:.4f}')
    return wrapper

def fake_sleep(sec):
    print(f'executing {fake_sleep.__name__}...')
    time.sleep(sec)
    
fake_sleep(2)
# Out:
# executing fake_sleep...

# %%
timer(fake_sleep)(3)
# Out:
# executing fake_sleep...
# Execution time 3.0013

# %%
import time

def timer(func):
    def wrapper(sec):
        start = time.time()
        func(sec)
        stop = time.time()
        print(f'Execution time {stop-start:.4f}')
    return wrapper

@timer
def fake_sleep(sec):
    print(f'executing {fake_sleep.__name__}...')
    time.sleep(sec)

# %%
fake_sleep(3)
# Out:
# executing wrapper...
# Execution time 3.0007

# %%
class Phone:
    
    def __init__(self, price):
        self._price = price
     
    @property     
    def price(self):
        print('getting...')
        return self._price

# %%
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Phone.__init__(self, price)>,
#               'price': <property at 0x273e108dee0>,
#               '__static_attributes__': ('_price',),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>,
#               '__doc__': None})

# %%
phone = Phone(2000)

# %%
phone.price
# Out:
# getting...
# 2000

# %%
class Phone:
    """phone class docs."""
    
    def __init__(self, price):
        self._price = price
    
    @property
    def price(self):
        print('Getting price...')
        return self._price
    
    @price.setter
    def price(self,price):
        print('setting...')
        if isinstance(price,(int,float)):
            if price > 0: 
                self._price = price
            else:
                raise ValueError('price must be positive')
        else: 
            raise TypeError('price must be float or int')

# %%
phone = Phone(12000)
phone.price
# Out:
# Getting price...
# 12000

# %%
phone.price = -1111
# Out:
# setting...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 phone.price = -1111
#
# Cell In[18], line 19, in Phone.price(self, price)
#      17         self._price = price
#      18     else:
# ---> 19         raise ValueError('price must be positive')
#      20 else:
#      21     raise TypeError('price must be float or int')
#
# ValueError: price must be positive

# %%
phone.price = 2222
phone.price
# Out:
# setting...
# Getting price...
# 2222

# %%
class Phone:
    """phone class docs."""
    
    def __init__(self, price):
        self._price = price
    
    @property
    def price(self):
        print('Getting price...')
        return self._price
    
    
    @price.setter
    def price(self,price):
        print('setting...')
        if isinstance(price,(int,float)):
            if price > 0: 
                self._price = price
            else:
                raise ValueError('price must be positive')
        else: 
            raise TypeError('price must be float or int')
      
    @price.deleter
    def price(self):
        print('deletting...')
        del self._price

# %%
phone = Phone(4444)
phone.price
# Out:
# Getting price...
# 4444

# %%
del phone.price
# Out:
# deletting...

# %%
phone2 = Phone('Apple')
phone2.price
# Out:
# Getting price...
# 'Apple'

# %%
class Phone:
    """phone class docs."""
    
    def __init__(self, price):
        self.price = price
    
    @property
    def price(self):
        print('Getting price...')
        return self._price
    
    
    @price.setter
    def price(self,price):
        print('setting...')
        if isinstance(price,(int,float)):
            if price > 0: 
                self._price = price
            else:
                raise ValueError('price must be positive')
        else: 
            raise TypeError('price must be float or int')
      
    @price.deleter
    def price(self):
        print('deletting...')
        del self._price

# %%
phone2 = Phone('Apple')
phone2.price
# Out:
# setting...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 phone2 = Phone('Apple')
#       2 phone2.price
#
# Cell In[27], line 5, in Phone.__init__(self, price)
#       4 def __init__(self, price):
# ----> 5     self.price = price
#
# Cell In[27], line 22, in Phone.price(self, price)
#      20         raise ValueError('price must be positive')
#      21 else:
# ---> 22     raise TypeError('price must be float or int')
#
# TypeError: price must be float or int

# %%
class Game: 
    
    def __init__(self,level=0):
        self.level = level 
        
    @property    
    def level(self):
        return self._level 
    
    @level.setter
    def level(self, value):
        if value < 0:
            self._level = 0 
        elif value > 100:
            self._level = 100 
        else: 
            self._level = value

# %%
games = [Game(),Game(10),Game(-10),Game(110)]
games

# %%
[game.level for game in games]
# Out:
# [0, 10, 0, 100]

# %% [markdown]
# ## metody specjalne

# %% [markdown]
# ### __new__() + __init__()

# %%
dir(object)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
class Company:
     """The company class docs."""
     
     def __init__(self, name):
         self.name = name
         
company = Company('Apple')
company.__dict__
# Out:
# {'name': 'Apple'}

# %%
company2 =Company.__new__(Company)

# %%
company2

# %%
company2.__init__('Microsoft')

# %%
company2.__dict__
# Out:
# {'name': 'Microsoft'}

# %%
class Student:
    
    students = []
    limit = 3 
    
    def __new__(cls): 
        if len(cls.students) >= cls.limit: 
            raise RuntimeError('Limit of students exceeded')
        instance = object.__new__(cls)
        cls.students.append(instance)
        return instance

# %%
s1 = Student()
s2 = Student()
s3 = Student()

# %%
Student.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'students': [<__main__.Student at 0x146a9aadd30>,
# ...
#               'limit': 3,
#               '__new__': <staticmethod(<function Student.__new__ at 0x00000146A9B48B80>)>,
#               '__static_attributes__': (),
#               '__dict__': <attribute '__dict__' of 'Student' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Student' objects>,
#               '__doc__': None})

# %%
s4= Student()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 s4= Student()
#
# Cell In[14], line 8, in Student.__new__(cls)
#       6 def __new__(cls):
#       7     if len(cls.students) >= cls.limit:
# ----> 8         raise RuntimeError('Limit of students exceeded')
#       9     instance = object.__new__(cls)
#      10     cls.students.append(instance)
#
# RuntimeError: Limit of students exceeded

# %% [markdown]
# ### __repr__

# %%
repr(object)
# Out:
# "<class 'object'>"

# %%
class Phone:
    
    def __init__(self, brand):
        self.brand = brand
        
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Phone.__init__(self, brand)>,
#               '__static_attributes__': ('brand',),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>,
#               '__doc__': None})

# %%
repr(Phone)
# Out:
# "<class '__main__.Phone'>"

# %%
phone = Phone('Apple')

# %%
repr(phone)
# Out:
# '<__main__.Phone object at 0x00000146A9AAECF0>'

# %%
class Phone:
    
    def __init__(self, brand):
        self.brand = brand
        
    def __repr__(self):
        return f"Phone(brand='{self.brand}')"
        
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Phone.__init__(self, brand)>,
#               '__repr__': <function __main__.Phone.__repr__(self)>,
#               '__static_attributes__': ('brand',),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>,
#               '__doc__': None})

# %%
phone = Phone('Apple')

# %%
phone
# Out:
# Phone(brand='Apple')

# %%
repr(phone)
# Out:
# "Phone(brand='Apple')"

# %%
print(phone)
# Out:
# Phone(brand='Apple')

# %%
eval(repr(phone))
# Out:
# Phone(brand='Apple')

# %%
phone2 = eval(repr(phone))

# %%
phone2.brand
# Out:
# 'Apple'

# %% [markdown]
# ### str

# %%
class Phone:
    
    def __init__(self, brand):
        self.brand = brand
        
    def __repr__(self):
        return f"Phone(brand='{self.brand}')"
    
    def __str__(self):
        return f'{self.brand} brand mobile phone'
        
Phone.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Phone.__init__(self, brand)>,
#               '__repr__': <function __main__.Phone.__repr__(self)>,
#               '__str__': <function __main__.Phone.__str__(self)>,
#               '__static_attributes__': ('brand',),
#               '__dict__': <attribute '__dict__' of 'Phone' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Phone' objects>,
#               '__doc__': None})

# %%
phone = Phone('Apple')

# %%
phone
# Out:
# Phone(brand='Apple')

# %%
repr(phone)
# Out:
# "Phone(brand='Apple')"

# %%
print(phone)
# Out:
# Apple brand mobile phone

# %%
str(phone)
# Out:
# 'Apple brand mobile phone'

# %% [markdown]
# ### len

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
class Point: 
    
    def __init__(self, *coords):
        for value in coords:
            if not isinstance(value, (int, float)):
                raise TypeError('Coordinates must be numbers')
        self._coords = coords
        
    def __repr__(self):
        return f'Point(coords = {self._coords})'
    
    @property
    def coords(self):
        return self._coords

# %%
p = Point(1,2)

# %%
p.__dict__
# Out:
# {'_coords': (1, 2)}

# %%
p
# Out:
# Point(coords = (1, 2))

# %%
p = Point(1,2,5)

# %%
p
# Out:
# Point(coords = (1, 2, 5))

# %%
p = Point(1,2,'dss')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 p = Point(1,2,'dss')
#
# Cell In[46], line 6, in Point.__init__(self, *coords)
#       4 for value in coords:
#       5     if not isinstance(value, (int, float)):
# ----> 6         raise TypeError('Coordinates must be numbers')
#       7 self._coords = coords
#
# TypeError: Coordinates must be numbers

# %%
len(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 len(p)
#
# TypeError: object of type 'Point' has no len()

# %%
class Point: 
    
    def __init__(self, *coords):
        for value in coords:
            if not isinstance(value, (int, float)):
                raise TypeError('Coordinates must be numbers')
        self._coords = coords
        
    def __repr__(self):
        return f'Point(coords = {self._coords})'
    
    def __len__(self):
        return len(self._coords)
    
    @property
    def coords(self):
        return self._coords

# %%
q = Point(1,2,3,4,5)

# %%
len(q)
# Out:
# 5

# %% [markdown]
# ### bool

# %%
 print(bool(q))
# Out:
# True

# %%
z = Point()

# %%
print(bool(z))
# Out:
# False

# %%
class Point: 
    
    def __init__(self, *coords):
        for value in coords:
            if not isinstance(value, (int, float)):
                raise TypeError('Coordinates must be numbers')
        self._coords = coords
        
    def __repr__(self):
        return f'Point(coords = {self._coords})'
    
    @property
    def coords(self):
        return self._coords

# %%
z = Point()
x = Point(1,2,3)

# %%
bool(z), bool(x)
# Out:
# (True, True)

# %%
class Point: 
    
    def __init__(self, *coords):
        for value in coords:
            if not isinstance(value, (int, float)):
                raise TypeError('Coordinates must be numbers')
        self._coords = coords
        
    def __repr__(self):
        return f'Point(coords = {self._coords})'
    
    def __len__(self):
        return len(self._coords)
    
    def __bool__(self):
        return sum(self._coords) != 0
    
    @property
    def coords(self):
        return self._coords

# %%
p = Point(1,2,3)
z = Point(1,0,-1)

# %%
bool(z), bool(p)
# Out:
# (False, True)

# %% [markdown]
# ## operatory 2 argumentowe

# %% [markdown]
# ### add

# %%
p1 = Point(1,2,3)
p2 = Point(1,2,3)
p1 + p2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 3
#       1 p1 = Point(1,2,3)
#       2 p2 = Point(1,2,3)
# ----> 3 p1 + p2
#
# TypeError: unsupported operand type(s) for +: 'Point' and 'Point'

# %%
class Point: 
    
    def __init__(self, *coords):
        for value in coords:
            if not isinstance(value, (int, float)):
                raise TypeError('Coordinates must be numbers')
        self._coords = coords
        
    def __repr__(self):
        return f'Point(coords = {self._coords})'
    
    def __len__(self):
        return len(self._coords)
    
    def __bool__(self):
        return sum(self._coords) != 0
    
    def __add__(self, other):
        coords = tuple(x+y for x,y in zip(self._coords, other._coords))
        return Point(*coords)
    
    
    @property
    def coords(self):
        return self._coords

# %%
p1 = Point(1,2,3)
p2 = Point(1,2,3)
p1 + p2
# Out:
# Point(coords = (2, 4, 6))

# %%
p1 = Point(1,2)
p2 = Point(1,2,3)
p1 + p2
# Out:
# Point(coords = (2, 4))

# %%
p1.__add__(p2)
# Out:
# Point(coords = (2, 4))

# %%
p1 + 5
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 p1 + 5
#
# Cell In[69], line 19, in Point.__add__(self, other)
#      18 def __add__(self, other):
# ---> 19     coords = tuple(x+y for x,y in zip(self._coords, other._coords))
#      20     return Point(*coords)
#
# AttributeError: 'int' object has no attribute '_coords'

# %%
class Point: 
    
    def __init__(self, *coords):
        for value in coords:
            if not isinstance(value, (int, float)):
                raise TypeError('Coordinates must be numbers')
        self._coords = coords
        
    def __repr__(self):
        return f'Point(coords = {self._coords})'
    
    def __len__(self):
        return len(self._coords)
    
    def __bool__(self):
        return sum(self._coords) != 0
    
    def __add__(self, other):
        if not isinstance(other, Point):
            raise NotImplemented 
        coords = tuple(x+y for x,y in zip(self._coords, other._coords))
        return Point(*coords)
    
    
    @property
    def coords(self):
        return self._coords

# %%
p1 = Point(1,2)
p2 = Point(1,2,3)
p1 + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 3
#       1 p1 = Point(1,2)
#       2 p2 = Point(1,2,3)
# ----> 3 p1 + 5
#
# Cell In[76], line 20, in Point.__add__(self, other)
#      18 def __add__(self, other):
#      19     if not isinstance(other, Point):
# ---> 20         raise NotImplemented
#      21     coords = tuple(x+y for x,y in zip(self._coords, other._coords))
#      22     return Point(*coords)
#
# TypeError: exceptions must derive from BaseException

# %% [markdown]
# ### sub

# %%
p1 = Point(1,2)
p2 = Point(1,2,3)
p1 - p2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 3
#       1 p1 = Point(1,2)
#       2 p2 = Point(1,2,3)
# ----> 3 p1 - p2
#
# TypeError: unsupported operand type(s) for -: 'Point' and 'Point'

# %%
class Point: 
    
    def __init__(self, *coords):
        for value in coords:
            if not isinstance(value, (int, float)):
                raise TypeError('Coordinates must be numbers')
        self._coords = coords
        
    def __repr__(self):
        return f'Point(coords = {self._coords})'
    
    def __len__(self):
        return len(self._coords)
    
    def __bool__(self):
        return sum(self._coords) != 0
    
    def __add__(self, other):
        if not isinstance(other, Point):
            raise NotImplemented 
        coords = tuple(x+y for x,y in zip(self._coords, other._coords))
        return Point(*coords)
    
    def __sub__(self, other):
        if not isinstance(other, Point):
            raise NotImplemented
        coords = tuple(x-y for x,y in zip(self._coords, other._coords))
        return Point(*coords)
    
    @property
    def coords(self):
        return self._coords

# %%
p1 = Point(1,4)
p2 = Point(1,2)
p1 - p2
# Out:
# Point(coords = (0, 2))

# %%
p1.__sub__(p2)
# Out:
# Point(coords = (0, 2))

# %% [markdown]
# ### mul

# %%
p1 = Point(1,4)
p2 = Point(1,2)
p1 * p2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 3
#       1 p1 = Point(1,4)
#       2 p2 = Point(1,2)
# ----> 3 p1 * p2
#
# TypeError: unsupported operand type(s) for *: 'Point' and 'Point'

# %%
class Point: 
    
    def __init__(self, *coords):
        for value in coords:
            if not isinstance(value, (int, float)):
                raise TypeError('Coordinates must be numbers')
        self._coords = coords
        
    def __repr__(self):
        return f'Point(coords = {self._coords})'
    
    def __len__(self):
        return len(self._coords)
    
    def __bool__(self):
        return sum(self._coords) != 0
    
    def __add__(self, other):
        if not isinstance(other, Point):
            raise NotImplemented 
        coords = tuple(x+y for x,y in zip(self._coords, other._coords))
        return Point(*coords)
    
    def __sub__(self, other):
        if not isinstance(other, Point):
            raise NotImplemented
        coords = tuple(x-y for x,y in zip(self._coords, other._coords))
        return Point(*coords)
    
    def __mul__(self, other):
            if not isinstance(other, Point):
                raise NotImplemented
            coords = tuple(x*y for x,y in zip(self._coords, other._coords))
            return Point(*coords)
    
    @property
    def coords(self):
        return self._coords

# %%
p1 = Point(1,4)
p2 = Point(1,2)
p1 * p2
# Out:
# Point(coords = (1, 8))

# %%
p1.__mul__(p2)
# Out:
# Point(coords = (1, 8))

# %% [markdown]
# ### truediv , floordiv

# %%
p1 / p2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 p1 / p2
#
# TypeError: unsupported operand type(s) for /: 'Point' and 'Point'

# %%
p1 // p2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 p1 // p2
#
# TypeError: unsupported operand type(s) for //: 'Point' and 'Point'

# %%
class Point: 
    
    def __init__(self, *coords):
        for value in coords:
            if not isinstance(value, (int, float)):
                raise TypeError('Coordinates must be numbers')
        self._coords = coords
        
    def __repr__(self):
        return f'Point(coords = {self._coords})'
    
    def __len__(self):
        return len(self._coords)
    
    def __bool__(self):
        return sum(self._coords) != 0
    
    def __add__(self, other):
        if not isinstance(other, Point):
            raise NotImplemented 
        coords = tuple(x+y for x,y in zip(self._coords, other._coords))
        return Point(*coords)
    
    def __sub__(self, other):
        if not isinstance(other, Point):
            raise NotImplemented
        coords = tuple(x-y for x,y in zip(self._coords, other._coords))
        return Point(*coords)
    
    def __mul__(self, other):
            if not isinstance(other, Point):
                raise NotImplemented
            coords = tuple(x*y for x,y in zip(self._coords, other._coords))
            return Point(*coords)
        
    def __truediv__(self, other):
            if not isinstance(other, Point):
                raise NotImplemented
            for coord in other._coords:
                if coord == 0:
                    raise ZeroDivisionError('division by zero')
            coords = tuple(x/y for x,y in zip(self._coords, other._coords))
            return Point(*coords)
        
    def __floordiv__(self, other):
            if not isinstance(other, Point):
                raise NotImplemented
            for coord in other._coords:
                if coord == 0:
                    raise ZeroDivisionError('division by zero')
            coords = tuple(x//y for x,y in zip(self._coords, other._coords))
            return Point(*coords)
    
    @property
    def coords(self):
        return self._coords

# %%
p1 = Point(1,4)
p2 = Point(1,2)
p1 / p2, p1 // p2
# Out:
# (Point(coords = (1.0, 2.0)), Point(coords = (1, 2)))

# %%
p1 = Point(1,4)
p2 = Point(1,0)
p1 / p2, p1 // p2
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[99], line 3
#       1 p1 = Point(1,4)
#       2 p2 = Point(1,0)
# ----> 3 p1 / p2, p1 // p2
#
# Cell In[97], line 41, in Point.__truediv__(self, other)
#      39 for coord in other._coords:
#      40     if coord == 0:
# ---> 41         raise ZeroDivisionError('division by zero')
#      42 coords = tuple(x/y for x,y in zip(self._coords, other._coords))
#      43 return Point(*coords)
#
# ZeroDivisionError: division by zero

# %%
class Doc:
    
    def __init__(self, string):
        self.string = string
        
Doc.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Doc.__init__(self, string)>,
#               '__static_attributes__': ('string',),
#               '__dict__': <attribute '__dict__' of 'Doc' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Doc' objects>,
#               '__doc__': None})

# %%
doc1 = Doc('object')
doc2 = Doc('oritented')
doc3 = Doc('programming')

# %%
doc1 + doc2 + doc3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 doc1 + doc2 + doc3
#
# TypeError: unsupported operand type(s) for +: 'Doc' and 'Doc'

# %%
class Doc:
    
    def __init__(self, string):
        self.string = string
    
    def __repr__(self):
        return f'Doc(string = {self.string})'
    
    def __str__(self):
        return f'{self.string}'
    
    def __add__(self, other):
        if not isinstance(other, Doc):
            raise NotImplemented
        return Doc(self.string + ' ' + other.string)
        
Doc.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Doc.__init__(self, string)>,
#               '__repr__': <function __main__.Doc.__repr__(self)>,
#               '__str__': <function __main__.Doc.__str__(self)>,
#               '__add__': <function __main__.Doc.__add__(self, other)>,
#               '__static_attributes__': ('string',),
#               '__dict__': <attribute '__dict__' of 'Doc' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Doc' objects>,
#               '__doc__': None})

# %%
doc1 = Doc('object')
doc2 = Doc('oritented')
doc3 = Doc('programming')

doc4 = doc1 + doc2 + doc3

# %%
print(doc4)
# Out:
# object oritented programming
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Rozszerzone przypisanie

# %%
class Doc:
    
    def __init__(self, string):
        self.string = string
    
    def __repr__(self):
        return f'Doc(string = {self.string})'
    
    def __str__(self):
        return f'{self.string}'
    
    def __add__(self, other):
        if not isinstance(other, Doc):
            raise NotImplemented
        return Doc(self.string + ' ' + other.string)
        
Doc.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Doc.__init__(self, string)>,
#               '__repr__': <function __main__.Doc.__repr__(self)>,
#               '__str__': <function __main__.Doc.__str__(self)>,
#               '__add__': <function __main__.Doc.__add__(self, other)>,
#               '__static_attributes__': ('string',),
#               '__dict__': <attribute '__dict__' of 'Doc' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Doc' objects>,
#               '__doc__': None})

# %%
doc1 = Doc('object')
doc2 = Doc('oritented')
doc3 = Doc('programming')

doc1 += doc2

# %%
doc1
# Out:
# Doc(string = object oritented)

# %%
class Doc:
    
    def __init__(self, string):
        self.string = string
    
    def __repr__(self):
        return f'Doc(string = {self.string})'
    
    def __str__(self):
        return f'{self.string}'
    
    def __add__(self, other):
        if not isinstance(other, Doc):
            raise NotImplemented
        return Doc(self.string + ' ' + other.string)
    
    def __iadd__(self, other):
            if not isinstance(other, Doc):
                raise NotImplemented
            return Doc(self.string + '-' + other.string)
        
Doc.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Doc.__init__(self, string)>,
#               '__repr__': <function __main__.Doc.__repr__(self)>,
#               '__str__': <function __main__.Doc.__str__(self)>,
#               '__add__': <function __main__.Doc.__add__(self, other)>,
#               '__iadd__': <function __main__.Doc.__iadd__(self, other)>,
#               '__static_attributes__': ('string',),
#               '__dict__': <attribute '__dict__' of 'Doc' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Doc' objects>,
#               '__doc__': None})

# %%
doc1 = Doc('object')
doc2 = Doc('oritented')
doc3 = Doc('programming')

doc1 += doc2

# %%
doc1
# Out:
# Doc(string = object-oritented)

# %% [markdown]
# ## operatory porównania

# %%
help(object.__eq__)
# Out:
# Help on wrapper_descriptor:
#
# __eq__(self, value, /) unbound builtins.object method
#     Return self==value.

# %%
class Doc:
    
    def __init__(self, string):
        self.string = string
    
    def __repr__(self):
        return f'Doc(string = {self.string})'
    
    def __str__(self):
        return f'{self.string}'
    
    def __add__(self, other):
        if not isinstance(other, Doc):
            raise NotImplemented
        return Doc(self.string + ' ' + other.string)
    
    def __iadd__(self, other):
            if not isinstance(other, Doc):
                raise NotImplemented
            return Doc(self.string + '-' + other.string)
        
    
        
Doc.__dict__

# %%
doc1 = Doc('ABC')
doc2 = Doc('XYZ')

# %%
doc1 == doc2
# Out:
# False

# %%
doc1 = Doc('XYZ')
doc2 = Doc('XYZ')

# %%
doc1 == doc2
# Out:
# False

# %%
id(doc1), id(doc2)
# Out:
# (2228566534224, 2228566535504)

# %%
doc3 = doc1

# %%
doc3 == doc1
# Out:
# True

# %%
id(doc1), id(doc3)
# Out:
# (2228566534224, 2228566534224)

# %%
class Doc:
    
    def __init__(self, string):
        self.string = string
    
    def __repr__(self):
        return f'Doc(string = {self.string})'
    
    def __str__(self):
        return f'{self.string}'
    
    def __add__(self, other):
        if not isinstance(other, Doc):
            raise NotImplemented
        return Doc(self.string + ' ' + other.string)
    
    def __iadd__(self, other):
            if not isinstance(other, Doc):
                raise NotImplemented
            return Doc(self.string + '-' + other.string)
        
    def __eq__(self, other):
        if not isinstance(other, Doc):
            raise NotImplemented
        return len(self.string) == len(other.string)
        
    
        
Doc.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Doc.__init__(self, string)>,
#               '__repr__': <function __main__.Doc.__repr__(self)>,
#               '__str__': <function __main__.Doc.__str__(self)>,
#               '__add__': <function __main__.Doc.__add__(self, other)>,
#               '__iadd__': <function __main__.Doc.__iadd__(self, other)>,
#               '__eq__': <function __main__.Doc.__eq__(self, other)>,
#               '__static_attributes__': ('string',),
#               '__dict__': <attribute '__dict__' of 'Doc' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Doc' objects>,
#               '__doc__': None,
#               '__hash__': None})

# %%
doc1 = Doc('ABC')
doc2 = Doc('XYZ')

# %%
doc1 == doc2
# Out:
# True

# %%
doc1 = Doc('ABCD')
doc2 = Doc('XYZ')

# %%
doc1 == doc2
# Out:
# False

# %%
doc1 != doc2
# Out:
# True

# %% [markdown]
# ### __lt__()

# %%
class Doc:
    
    def __init__(self, string):
        self.string = string
    
    def __repr__(self):
        return f'Doc(string = {self.string})'
    
    def __str__(self):
        return f'{self.string}'
    
    def __add__(self, other):
        if not isinstance(other, Doc):
            raise NotImplemented
        return Doc(self.string + ' ' + other.string)
    
    def __iadd__(self, other):
            if not isinstance(other, Doc):
                raise NotImplemented
            return Doc(self.string + '-' + other.string)
        
    def __eq__(self, other):
        if not isinstance(other, Doc):
            raise NotImplemented
        return len(self.string) == len(other.string)
        
    
        
Doc.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Doc.__init__(self, string)>,
#               '__repr__': <function __main__.Doc.__repr__(self)>,
#               '__str__': <function __main__.Doc.__str__(self)>,
#               '__add__': <function __main__.Doc.__add__(self, other)>,
#               '__iadd__': <function __main__.Doc.__iadd__(self, other)>,
#               '__eq__': <function __main__.Doc.__eq__(self, other)>,
#               '__static_attributes__': ('string',),
#               '__dict__': <attribute '__dict__' of 'Doc' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Doc' objects>,
#               '__doc__': None,
#               '__hash__': None})

# %%
doc1 = Doc('ABCD')
doc2 = Doc('XYZ')

# %%
doc1 > doc2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 doc1 > doc2
#
# TypeError: '>' not supported between instances of 'Doc' and 'Doc'

# %%
class Doc:
    
    def __init__(self, string):
        self.string = string
    
    def __repr__(self):
        return f'Doc(string = {self.string})'
    
    def __str__(self):
        return f'{self.string}'
    
    def __add__(self, other):
        if not isinstance(other, Doc):
            raise NotImplemented
        return Doc(self.string + ' ' + other.string)
    
    def __iadd__(self, other):
            if not isinstance(other, Doc):
                raise NotImplemented
            return Doc(self.string + '-' + other.string)
        
    def __eq__(self, other):
        if not isinstance(other, Doc):
            raise NotImplemented
        return len(self.string) == len(other.string)
    
    def __lt__(self, other):
        if not isinstance(other, Doc):
            raise NotImplemented
        return len(self.string) < len(other.string)
        
    
        
Doc.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Doc.__init__(self, string)>,
#               '__repr__': <function __main__.Doc.__repr__(self)>,
#               '__str__': <function __main__.Doc.__str__(self)>,
#               '__add__': <function __main__.Doc.__add__(self, other)>,
#               '__iadd__': <function __main__.Doc.__iadd__(self, other)>,
#               '__eq__': <function __main__.Doc.__eq__(self, other)>,
#               '__lt__': <function __main__.Doc.__lt__(self, other)>,
#               '__static_attributes__': ('string',),
#               '__dict__': <attribute '__dict__' of 'Doc' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Doc' objects>,
#               '__doc__': None,
#               '__hash__': None})

# %%
doc1 = Doc('ABCD')
doc2 = Doc('XYZ')

# %%
doc1 < doc2
# Out:
# False

# %%
doc1 <= doc2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 doc1 <= doc2
#
# TypeError: '<=' not supported between instances of 'Doc' and 'Doc'

# %%
class Doc:
    
    def __init__(self, string):
        self.string = string
    
    def __repr__(self):
        return f'Doc(string = {self.string})'
    
    def __str__(self):
        return f'{self.string}'
    
    def __add__(self, other):
        if not isinstance(other, Doc):
            raise NotImplemented
        return Doc(self.string + ' ' + other.string)
    
    def __iadd__(self, other):
            if not isinstance(other, Doc):
                raise NotImplemented
            return Doc(self.string + '-' + other.string)
        
    def __eq__(self, other):
        if not isinstance(other, Doc):
            raise NotImplemented
        return len(self.string) == len(other.string)
    
    def __lt__(self, other):
        if not isinstance(other, Doc):
            raise NotImplemented
        return len(self.string) < len(other.string)
    
    def __le__(self, other):
        if not isinstance(other, Doc):
            raise NotImplemented
        return len(self.string) <= len(other.string)
        
    
        
Doc.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Doc.__init__(self, string)>,
#               '__repr__': <function __main__.Doc.__repr__(self)>,
#               '__str__': <function __main__.Doc.__str__(self)>,
#               '__add__': <function __main__.Doc.__add__(self, other)>,
#               '__iadd__': <function __main__.Doc.__iadd__(self, other)>,
#               '__eq__': <function __main__.Doc.__eq__(self, other)>,
#               '__lt__': <function __main__.Doc.__lt__(self, other)>,
#               '__le__': <function __main__.Doc.__le__(self, other)>,
#               '__static_attributes__': ('string',),
#               '__dict__': <attribute '__dict__' of 'Doc' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Doc' objects>,
#               '__doc__': None,
#               '__hash__': None})

# %%
doc1 = Doc('ABCD')
doc2 = Doc('XYZ')
doc1 <= doc2
# Out:
# False

# %% [markdown]
# ### hash()

# %%
help(hash)
# Out:
# Help on built-in function hash in module builtins:
#
# hash(obj, /)
#     Return the hash value for the given object.
#
#     Two objects that compare equal must also have the same hash value, but the
#     reverse is not necessarily true.

# %%
class Doc:
    pass

doc1 = Doc()
doc2 = Doc()

doc1, doc2
# Out:
# (<__main__.Doc at 0x206e0f31fd0>, <__main__.Doc at 0x206e0f0c690>)

# %%
hash(doc1), hash(doc2)
# Out:
# (139285443069, 139285433449)

# %%
docs = {doc1,doc2}

# %%
class Doc:
    
    def __init__(self, string):
        self.string = string
        
    def __eq__(self, other):
        if not isinstance(other, Doc):
            raise NotImplemented
        return self.string == other.string

doc1 = Doc('ABC')
doc2 = Doc('ABC')
doc3 = Doc('XYZ')

doc1, doc2, doc3
# Out:
# (<__main__.Doc at 0x206e0f32a50>,
# ...
#  <__main__.Doc at 0x206e0f0da90>)

# %%
hash(doc1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 hash(doc1)
#
# TypeError: unhashable type: 'Doc'

# %%
docs = {doc1, doc2}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 docs = {doc1, doc2}
#
# TypeError: unhashable type: 'Doc'

# %%
class Doc:
    
    def __init__(self, string):
        self.string = string
        
    def __eq__(self, other):
        if not isinstance(other, Doc):
            raise NotImplemented
        return self.string == other.string
    
    def __hash__(self):
        return hash(self.string)

doc1 = Doc('ABC')
doc2 = Doc('ABC')
doc3 = Doc('XYZ')

doc1, doc2, doc3
# Out:
# (<__main__.Doc at 0x206e0f32ba0>,
# ...
#  <__main__.Doc at 0x206e0f0e5d0>)

# %%
hash(doc1), hash(doc2), hash(doc3)
# Out:
# (-3951482676273783874, -3951482676273783874, 8009353138126215838)

# %%
docs = {doc1,doc2}

# %% [markdown]
# ### call()

# %%
class Doc:
    
    def __init__(self, string):
        self.string = string
        
    def __repr__(self):
        return f'Doc(string = {self.string})'

# %%
doc1  = Doc('ABC')
doc1
# Out:
# Doc(string = ABC)

# %%
doc1()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 doc1()
#
# TypeError: 'Doc' object is not callable

# %%
class Doc:
    
    def __init__(self, string):
        self.string = string
        
    def __repr__(self):
        return f'Doc(string = {self.string})'
    
    def __call__(self):
        print(f'Calling {self}')

# %%
doc1  = Doc('ABC')
doc1
# Out:
# Doc(string = ABC)

# %%
doc1()
# Out:
# Calling Doc(string = ABC)

# %%
class Integer: 
    
    def __init__(self, value = 0):
        self.value = int(value)
        
    def __str__(self):
        return f'Integer class (value = {self.value})'
    
    def __repr__(self):
        return f'Integer(value = {self.value})'
    
    def __add__(self, other):
        if not isinstance(other, Integer):
            raise NotImplemented
        return Integer(self.value + other.value)
    
    def __sub__(self, other):
        if not isinstance(other, Integer):
            raise NotImplemented
        return Integer(self.value - other.value)

# %%
int1 = Integer('xyz')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 int1 = Integer('xyz')
#
# Cell In[2], line 4, in Integer.__init__(self, value)
#       3 def __init__(self, value = 0):
# ----> 4     self.value = int(value)
#
# ValueError: invalid literal for int() with base 10: 'xyz'

# %%
int2 = Integer(10)

# %%
int3 = Integer(20)

# %%
int2 + int3
# Out:
# Integer(value = 30)

# %% [markdown]
# ## Dziedziczenie

# %%
help(object)
# Out:
# Help on class object in module builtins:
#
# class object
#  |  The base class of the class hierarchy.
#  |
#  |  When called, it accepts no arguments and returns a new featureless
#  |  instance that has no instance attributes and cannot be given any.
#  |
#  |  Built-in subclasses:
#  |      anext_awaitable
#  |      async_generator
#  |      async_generator_asend
#  |      async_generator_athrow
#  |      ... and 92 other subclasses
#  |
#  |  Methods defined here:
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
#  |  __dir__(self, /)
#  |      Default dir() implementation.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Default object formatter.
#  |
#  |      Return str(self) if format_spec is empty. Raise TypeError otherwise.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
# ...

# %%
dir(object)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
class Vehicle(): 
    pass

# %%
help(Vehicle)
# Out:
# Help on class Vehicle in module __main__:
#
# class Vehicle(builtins.object)
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
Vehicle()

# %%
vehicle = Vehicle()

# %%
hash(vehicle)
# Out:
# 156897630653

# %% [markdown]
# ### dziedziczenie pojedyncze

# %%
class Vehicle(): 
    pass


class LandVehicle(Vehicle): 
    pass


class AirVehicle(Vehicle): 
    pass


class WaterVehicle(Vehicle):
    pass

# %%
vehicles = [Vehicle(), LandVehicle(), AirVehicle(), WaterVehicle()]

# %%
vehicles

# %%
issubclass(LandVehicle, Vehicle)
# Out:
# True

# %%
issubclass(Vehicle, LandVehicle)
# Out:
# False

# %%
issubclass(Vehicle, object)
# Out:
# True

# %%
issubclass(AirVehicle, object)
# Out:
# True

# %%
class Vehicle(): 
    pass


class LandVehicle(Vehicle): 
    pass


class Car(LandVehicle): 
    pass


class Truck(LandVehicle): 
    pass


class Bike(LandVehicle): 
    pass    


class AirVehicle(Vehicle): 
    pass


class Plane(AirVehicle): 
    pass


class Helicopter(AirVehicle): 
    pass


class WaterVehicle(Vehicle):
    pass

# %% [markdown]
# ### MRO

# %%
help(Plane)
# Out:
# Help on class Plane in module __main__:
#
# class Plane(AirVehicle)
#  |  Method resolution order:
#  |      Plane
#  |      AirVehicle
#  |      Vehicle
#  |      builtins.object
#  |
#  |  Data descriptors inherited from Vehicle:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
Plane.mro()
# Out:
# [__main__.Plane, __main__.AirVehicle, __main__.Vehicle, object]

# %%
Plane.__mro__
# Out:
# (__main__.Plane, __main__.AirVehicle, __main__.Vehicle, object)

# %% [markdown]
# ### nadpisywanie metod - method overriding

# %%
class Vehicle(): 
    
    def __init__(self, category):
        self.category = category


vehicle = Vehicle('land')
vehicle

# %%
repr(vehicle)
# Out:
# '<__main__.Vehicle object at 0x000002487D96DE80>'

# %%
class Vehicle(): 
    
    def __init__(self, category):
        self.category = category

    def __repr__(self):
        return f"Vehicle(category = '{self.category}')"

vehicle = Vehicle('land')
vehicle
# Out:
# Vehicle(category = 'land')

# %%
vehicle.__repr__()
# Out:
# "Vehicle(category = 'land')"

# %%
class Vehicle(): 
    
    def __init__(self, category = None):
        self.category = category if category else 'land'

    def __repr__(self):
        return f"Vehicle(category = '{self.category}')"

vehicle = Vehicle('land')
vehicle
# Out:
# Vehicle(category = 'land')
